# %%
import roifinder.src.segmenter
from roifinder.src.segmenter import *
# %matplotlib notebook

segmenter()
# Out:
# 2022-07-26 02:30:40.796743: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Extracted cells will be at:  /home/reshad812/CODES/GITHUB/ROI-Finder/annotated_XRF/raw_cells
# Matplotlib notebook environment must be called
# ...
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="799.5">
# <img src="data:image/png;base64,..." width="799.5">
# <img src="data:image/png;base64,..." width="799.5">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
