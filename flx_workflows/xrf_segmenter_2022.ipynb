# %% [markdown]
# # Notebook for finding parameters for binary conversion and cell extraction

# %%
import segmenter
from segmenter import *
# %matplotlib notebook
segmenter()
# Out:
# Extracted cells will be at:  /data02/AZC/ROI-Finder/annotated_XRF/raw_cells
# Matplotlib notebook environment must be called
# ...
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">
